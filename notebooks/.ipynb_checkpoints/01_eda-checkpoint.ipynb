# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style="whitegrid", palette="muted")
print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
df = pd.read_csv('../data/raw/ai4i2020.csv')

print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nNull Values:\n", df.isnull().sum())
print("\nTarget Distribution:\n", df['Machine failure'].value_counts())
# Out:
# Shape: (10000, 14)
#
# Columns: ['UDI', 'Product ID', 'Type', 'Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Machine failure', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF']
#
# Null Values:
#  UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Machine failure            0
# TWF                        0
# HDF                        0
# PWF                        0
# OSF                        0
# RNF                        0
# dtype: int64
#
# Target Distribution:
#  Machine failure
# 0    9661
# 1     339
# Name: count, dtype: int64

# %%
import os
os.makedirs('../reports/figures', exist_ok=True)

fig, ax = plt.subplots(figsize=(7, 4))
counts = df['Machine failure'].value_counts()
bars = ax.bar(['No Failure (0)', 'Failure (1)'],
               counts.values,
               color=['#4C9BE8', '#E8614C'],
               edgecolor='white', linewidth=1.2)
ax.bar_label(bars, fmt='%d', padding=4, fontsize=11)
ax.set_title('Machine Failure — Class Distribution', fontsize=14, pad=12)
ax.set_ylabel('Count')
plt.tight_layout()
plt.savefig('../reports/figures/01_class_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"Imbalance ratio: {counts[0]/counts[1]:.1f}:1")
# Out:
# Imbalance ratio: 28.5:1

# %%
numeric_cols = ['Air temperature [K]', 'Process temperature [K]',
                'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']

fig, axes = plt.subplots(2, 3, figsize=(14, 8))
axes = axes.flatten()

for i, col in enumerate(numeric_cols):
    axes[i].hist(df[col], bins=40, color='#5B8ECC', edgecolor='white', linewidth=0.5)
    axes[i].set_title(col, fontsize=10)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

axes[5].set_visible(False)
fig.suptitle('Feature Distributions', fontsize=14, y=1.01)
plt.tight_layout()
plt.savefig('../reports/figures/02_feature_distributions.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
corr_cols = ['Air temperature [K]', 'Process temperature [K]',
             'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]',
             'Machine failure']
corr = df[corr_cols].corr()

fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(corr,
            annot=True, fmt='.2f',
            cmap='coolwarm', center=0,
            linewidths=0.5, linecolor='white',
            square=True, ax=ax,
            cbar_kws={'shrink': 0.8})
ax.set_title('Feature Correlation Matrix', fontsize=14, pad=12)
plt.tight_layout()
plt.savefig('../reports/figures/03_correlation_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 5))
features_to_check = ['Torque [Nm]', 'Tool wear [min]', 'Rotational speed [rpm]']

for ax, feat in zip(axes, features_to_check):
    df.boxplot(column=feat, by='Machine failure', ax=ax,
               boxprops=dict(color='#4C9BE8'),
               medianprops=dict(color='#E8614C', linewidth=2))
    ax.set_title(feat, fontsize=10)
    ax.set_xlabel('Machine failure (0=No, 1=Yes)')

fig.suptitle('Feature Distribution by Failure Status', fontsize=13)
plt.tight_layout()
plt.savefig('../reports/figures/04_features_by_failure.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Failure types breakdown
failure_cols = ['TWF', 'HDF', 'PWF', 'OSF', 'RNF']
failure_counts = df[failure_cols].sum().sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(failure_counts.index, failure_counts.values,
              color=['#E8614C', '#4C9BE8', '#F5A623', '#7ED321', '#9B9B9B'],
              edgecolor='white', linewidth=1.2)
ax.bar_label(bars, fmt='%d', padding=4, fontsize=11)
ax.set_title('Failure Types Distribution', fontsize=14, pad=12)
ax.set_xlabel('Failure Type')
ax.set_ylabel('Count')
plt.tight_layout()
plt.savefig('../reports/figures/05_failure_types.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
scatter = ax.scatter(df['Air temperature [K]'],
                     df['Process temperature [K]'],
                     c=df['Machine failure'],
                     cmap='coolwarm', alpha=0.5, s=15)
plt.colorbar(scatter, ax=ax, label='Machine Failure')
ax.set_title('Air vs Process Temperature', fontsize=14)
ax.set_xlabel('Air Temperature [K]')
ax.set_ylabel('Process Temperature [K]')
plt.tight_layout()
plt.savefig('../reports/figures/06_temperature_scatter.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
df['Temp_diff'] = df['Process temperature [K]'] - df['Air temperature [K]']

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].hist(df[df['Machine failure']==0]['Temp_diff'], 
             bins=30, color='#4C9BE8', edgecolor='white', alpha=0.8)
axes[0].set_title('Temp Difference — Normal', fontsize=11)
axes[0].set_xlabel('Process - Air Temp [K]')

axes[1].hist(df[df['Machine failure']==1]['Temp_diff'], 
             bins=30, color='#E8614C', edgecolor='white', alpha=0.8)
axes[1].set_title('Temp Difference — Failure', fontsize=11)
axes[1].set_xlabel('Process - Air Temp [K]')

plt.tight_layout()
plt.savefig('../reports/figures/07_temp_difference.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 6))
normal = df[df['Machine failure'] == 0]
failure = df[df['Machine failure'] == 1]

ax.scatter(normal['Rotational speed [rpm]'], normal['Torque [Nm]'],
           alpha=0.3, s=10, color='#4C9BE8', label='Normal')
ax.scatter(failure['Rotational speed [rpm]'], failure['Torque [Nm]'],
           alpha=0.8, s=25, color='#E8614C', label='Failure', zorder=5)

ax.set_title('Rotational Speed vs Torque', fontsize=14)
ax.set_xlabel('Rotational Speed [rpm]')
ax.set_ylabel('Torque [Nm]')
ax.legend()
plt.tight_layout()
plt.savefig('../reports/figures/08_speed_vs_torque.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
type_failure = df.groupby('Type')['Machine failure'].agg(['sum', 'count'])
type_failure['failure_rate'] = (type_failure['sum'] / type_failure['count'] * 100).round(2)
print(type_failure)

fig, ax = plt.subplots(figsize=(7, 4))
bars = ax.bar(type_failure.index, type_failure['failure_rate'],
              color=['#4C9BE8', '#F5A623', '#E8614C'],
              edgecolor='white', linewidth=1.2)
ax.bar_label(bars, fmt='%.1f%%', padding=4, fontsize=11)
ax.set_title('Failure Rate by Product Type', fontsize=14)
ax.set_xlabel('Product Type (H=High, M=Medium, L=Low quality)')
ax.set_ylabel('Failure Rate (%)')
plt.tight_layout()
plt.savefig('../reports/figures/09_failure_by_type.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
#       sum  count  failure_rate
# Type
# H      21   1003          2.09
# L     235   6000          3.92
# M      83   2997          2.77
