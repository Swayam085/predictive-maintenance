# %%
# Week 4 Day 2 — Full Pipeline Documentation
# Author: Swayam Arya
# Branch: feature/swayam-ml

print("=" * 55)
print("PREDICTIVE MAINTENANCE — FULL PIPELINE DOCS")
print("Week 4 Day 2 — Swayam Arya")
print("=" * 55)
# Out:
# ...
# PREDICTIVE MAINTENANCE — FULL PIPELINE DOCS
# Week 4 Day 2 — Swayam Arya
# ...

# %%
import pandas as pd

pipeline = {
    "Week 1": {
        "Task": "IoT Telemetry Ingestion + Signal Processing",
        "Author": "Vrushabh (Data) + Swayam (ML)",
        "Files": "src/data_loader.py, src/features.py",
        "Output": "data/processed/featured_data.csv (10000, 19)",
        "Status": "✅ Complete"
    },
    "Week 2": {
        "Task": "Contextual Data Fusion + Ablation Study",
        "Author": "Swayam (ML)",
        "Files": "src/external_context.py, src/model.py",
        "Output": "data/processed/fused_data.csv (10000, 14)",
        "Status": "✅ Complete"
    },
    "Week 3": {
        "Task": "SMOTE + LightGBM + Threshold Tuning + SHAP",
        "Author": "Swayam (ML)",
        "Files": "src/model.py, notebooks/03_model.ipynb",
        "Output": "reports/figures/shap_summary.png, pr_curve.png",
        "Status": "✅ Complete"
    },
    "Week 4": {
        "Task": "Noise Analysis + Dashboard + Documentation",
        "Author": "Vrushabh (Dashboard) + Swayam (ML)",
        "Files": "dashboard/app.py, notebooks/04_noise_threshold_analysis.ipynb",
        "Output": "reports/figures/week4_analysis.png",
        "Status": "✅ Complete"
    }
}

df = pd.DataFrame(pipeline).T
print(df.to_string())
# Out:
#                                                Task                              Author                                                          Files                                          Output      Status
# Week 1  IoT Telemetry Ingestion + Signal Processing       Vrushabh (Data) + Swayam (ML)                            src/data_loader.py, src/features.py    data/processed/featured_data.csv (10000, 19)  ✅ Complete
# Week 2      Contextual Data Fusion + Ablation Study                         Swayam (ML)                          src/external_context.py, src/model.py       data/processed/fused_data.csv (10000, 14)  ✅ Complete
# Week 3   SMOTE + LightGBM + Threshold Tuning + SHAP                         Swayam (ML)                         src/model.py, notebooks/03_model.ipynb  reports/figures/shap_summary.png, pr_curve.png  ✅ Complete
# ...

# %%
metrics = {
    "Metric": [
        "Macro F1 — Baseline",
        "Macro F1 — With External Features",
        "Macro F1 — CV + SMOTE",
        "Tuned Threshold",
        "ROC-AUC",
        "Noise Robust upto",
        "SHAP Top Feature"
    ],
    "Value": [
        "0.8195",
        "0.8715",
        "0.8819",
        "0.8846",
        "0.9644",
        "Noise Level 0.10",
        "Torque_Nm"
    ],
    "Week": [
        "Week 2",
        "Week 2",
        "Week 3",
        "Week 4",
        "Week 3",
        "Week 4",
        "Week 3"
    ]
}

df_metrics = pd.DataFrame(metrics)
print(df_metrics.to_string(index=False))
# Out:
#                            Metric            Value   Week
#               Macro F1 — Baseline           0.8195 Week 2
# Macro F1 — With External Features           0.8715 Week 2
#             Macro F1 — CV + SMOTE           0.8819 Week 3
#                   Tuned Threshold           0.8846 Week 4
#                           ROC-AUC           0.9644 Week 3
#                 Noise Robust upto Noise Level 0.10 Week 4
#                  SHAP Top Feature        Torque_Nm Week 3

# %%
import os

print("=" * 60)
print("FILE STRUCTURE — ML Track")
print("=" * 60)

files = [
    ("src/model.py",                                "LightGBM + SMOTE + CV"),
    ("src/external_context.py",                     "External context fusion"),
    ("src/evaluate.py",                             "Evaluation functions"),
    ("dashboard/app.py",                            "Streamlit dashboard"),
    ("dashboard/data_feed.py",                      "Live sensor stream"),
    ("notebooks/03_model.ipynb",                    "Week 3 ML notebook"),
    ("notebooks/04_noise_threshold_analysis.ipynb", "Week 4 noise notebook"),
    ("reports/results.json",                        "Final metrics JSON"),
    ("reports/figures/shap_summary.png",            "SHAP summary plot"),
    ("reports/figures/pr_curve.png",                "PR curve"),
    ("reports/figures/week4_analysis.png",          "Week 4 analysis plot"),
]

for path, desc in files:
    exists = "✅" if os.path.exists(f"../{path}") else "❌"
    print(f"{exists}  {path:<50} {desc}")
# Out:
# ...
# FILE STRUCTURE — ML Track
# ...
# ✅  src/model.py                                       LightGBM + SMOTE + CV
# ✅  src/external_context.py                            External context fusion
# ✅  src/evaluate.py                                    Evaluation functions
# ✅  dashboard/app.py                                   Streamlit dashboard
# ✅  dashboard/data_feed.py                             Live sensor stream
# ✅  notebooks/03_model.ipynb                           Week 3 ML notebook
# ✅  notebooks/04_noise_threshold_analysis.ipynb        Week 4 noise notebook
# ✅  reports/results.json                               Final metrics JSON
# ✅  reports/figures/shap_summary.png                   SHAP summary plot
# ✅  reports/figures/pr_curve.png                       PR curve
# ✅  reports/figures/week4_analysis.png                 Week 4 analysis plot

# %%
print("=" * 55)
print("WEEK 4 DAY 2 — Pipeline Documentation Complete")
print("=" * 55)
print("✅ All 4 weeks documented")
print("✅ Macro F1 >= 0.85 achieved — 0.8819")
print("✅ ROC-AUC: 0.9644")
print("✅ Dashboard running — Streamlit")
print("✅ SHAP explainability added")
print("✅ GitHub commits — consistent weekly cadence")
print("=" * 55)
print("[DONE] Week 4 Day 2 complete!")
# Out:
# ...
# WEEK 4 DAY 2 — Pipeline Documentation Complete
# ...
# ✅ All 4 weeks documented
# ✅ Macro F1 >= 0.85 achieved — 0.8819
# ✅ ROC-AUC: 0.9644
# ✅ Dashboard running — Streamlit
# ✅ SHAP explainability added
# ✅ GitHub commits — consistent weekly cadence
# ...
# [DONE] Week 4 Day 2 complete!
